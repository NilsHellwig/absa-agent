# %%
import os

# LangSmith Configuration
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = "absa-agent-ddg"

from langsmith import Client
client = Client()
try:
    client.list_projects()
    print("Connection to LangSmith successful! Using project:", os.environ["LANGCHAIN_PROJECT"])
except Exception as e:
    print("Error connecting to LangSmith: Check your API key!")
    print(e)
# Out:
# Connection to LangSmith successful! Using project: absa-agent-ddg

# %%
import operator
import json
import requests
from typing import Annotated, TypedDict, List, Optional
from pydantic import BaseModel, Field
from bs4 import BeautifulSoup
from langchain_ollama import ChatOllama
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper
from langgraph.graph import StateGraph, END
from langsmith import traceable

# %%
LLM_MODEL = "gemma3:27b"
LLM_URL = "http://132.199.138.16:3333"
LLM_TEMPERATURE = 0

RETRIEVER_MAX_RESULTS = 50

# %%
# LLM Configuration (Ollama API)
llm = ChatOllama(
    model=LLM_MODEL,
    base_url=LLM_URL,
    temperature=LLM_TEMPERATURE,
    format="json" # Ensure the model supports JSON mode if possible
)

# Search wrapper for structured results
search_wrapper = DuckDuckGoSearchAPIWrapper()

# Helper to load prompts
def load_prompt(filename):
    with open(f"prompt_template/{filename}", "r") as f:
        return f.read()

# Define Pydantic models for structured output
class Review(BaseModel):
    review_title: Optional[str] = Field(description="Title of the review", default=None)
    review_text: str = Field(description="Content of the review")
    stars: Optional[int] = Field(description="Star rating", default=None)

class ExtractionResult(BaseModel):
    reviews: List[Review] = Field(description="List of extracted reviews")

# %%
# Graph State Definition
class GraphState(TypedDict):
    query: str
    retrieved_content: List[dict]
    relevant_ids: List[str]
    reviews: List[dict]
    summary: str # Keep for compatibility or future use

# %%
# Node 1: Retrieval
@traceable(run_type="retriever")
def retrieval_node(state: GraphState):
    print("--- RETRIEVAL ---")
    query = state["query"]
    results = search_wrapper.results(query, max_results=RETRIEVER_MAX_RESULTS)
    
    # Filter out TripAdvisor results
    filtered_results = [r for r in results if "tripadvisor" not in r['link'].lower()]
    
    relevant_ids = []
    for idx, result in enumerate(filtered_results):
        rid = f"result_{idx+1}"
        result["id"] = rid
        relevant_ids.append(rid)
    return {"retrieved_content": filtered_results, "relevant_ids": relevant_ids}

# Node 3: Extraction - Fetches content and extracts reviews using structured output
@traceable(run_type="llm")
def extract_reviews_node(state: GraphState):
    print("--- EXTRACT REVIEWS ---")
    relevant_ids = state.get("relevant_ids", [])
    results = state["retrieved_content"]
    all_reviews = []
    
    id_map = {r['id']: r for r in results}
    template = load_prompt("extract_reviews.txt")
    structured_llm = llm.with_structured_output(ExtractionResult)
    
    # Ensure _html directory exists
    if not os.path.exists("_html"):
        os.makedirs("_html")
    
    for rid in relevant_ids:
        if rid not in id_map: continue
        url = id_map[rid]['link']
        print(f"Fetching: {url}...")
        
        try:
            res = requests.get(url, timeout=10, headers={"User-Agent": "Mozilla/5.0"})
            if res.status_code != 200:
                print(f"Error loading {url}: Status {res.status_code}")
                continue
            
            # Save HTML content
            html_filename = f"_html/{rid}.html"
            with open(html_filename, "w", encoding="utf-8") as f:
                f.write(res.text)
                
            soup = BeautifulSoup(res.text, "html.parser")
            # Extract text, limit to ~8000 characters for context window
            page_text = soup.get_text(separator=" ", strip=True)[:8000]
            
            prompt = template.format(page_text=page_text)
            response = structured_llm.invoke(prompt)
            
            for rev in response.reviews:
                # Convert Pydantic model to dict and add URL
                rev_dict = rev.model_dump()
                rev_dict["website_url"] = url
                all_reviews.append(rev_dict)
                
        except Exception as e:
            print(f"Error at {url}: {e}")
            
    return {"reviews": all_reviews}

# Node 4: Summarization
@traceable(run_type="llm")
def summarize_reviews_node(state: GraphState):
    print("--- SUMMARIZE ---")
    reviews = state.get("reviews", [])
    query = state["query"]
    
    if not reviews:
        return {"summary": "No reviews found to summarize."}
        
    reviews_text = ""
    for idx, rev in enumerate(reviews):
        stars = f"({rev['stars']} stars)" if rev.get('stars') else ""
        reviews_text += f"Review {idx+1} {stars}: {rev['review_text']}\n\n"
        
    template = load_prompt("summarize_reviews.txt")
    prompt = template.format(query=query, reviews_text=reviews_text)
    
    # Since it's a summary, we can use the regular LLM instead of structured output (unless we want a JSON summary)
    response = llm.invoke(prompt)
    
    return {"summary": response.content}

# Graph Construction
workflow = StateGraph(GraphState)
workflow.add_node("retrieval", retrieval_node)
workflow.add_node("extract", extract_reviews_node)
workflow.add_node("summarize", summarize_reviews_node)

workflow.set_entry_point("retrieval")
workflow.add_edge("retrieval", "extract")
workflow.add_edge("extract", "summarize")
workflow.add_edge("summarize", END)

app = workflow.compile()
print("LangGraph with Extraction and Summarization created (Evaluation removed).")
# Out:
# LangGraph with Evaluation, Extraction and Summarization created.

# %%
# Test run with LangSmith configuration
config = {
    "tags": ["dev-test", "absa-summary"],
    "metadata": {
        "user": "nils",
        "model": LLM_MODEL
    }
}

# Query for reviews
inputs = {"query": "customer reviews for l'osteria pizza at regensburg"}

print("Starting agent run...")
final_reviews = []
final_summary = ""

for output in app.stream(inputs, config=config):
    for key, value in output.items():
        print(f"\n--- Node '{key}' finished ---")
        if key == "extract" and "reviews" in value:
            final_reviews = value["reviews"]
        if key == "summarize" and "summary" in value:
            final_summary = value["summary"]

print("\n" + "="*50)
print("SUMMARY:")
print(final_summary)

print("\n" + "="*50)
print(f"EXTRACTED REVIEWS ({len(final_reviews)} found):")
for i, rev in enumerate(final_reviews[:5]): # Show first 5
    print(f"\n[{i+1}] {rev.get('review_title', 'No Title')}")
    print(f"Stars: {rev.get('stars', 'N/A')} | URL: {rev.get('website_url')}")
    print(f"Text: {rev.get('review_text', '')[:150]}...")

print("\nDone!")
# Out:
# Starting agent run...
# --- RETRIEVAL ---
#
# --- Node 'retrieval' finished ---
# --- EVALUATE ---
# Relevant IDs found: ['result_2', 'result_3', 'result_7', 'result_8', 'result_9', 'result_13', 'result_14', 'result_15', 'result_18', 'result_20', 'result_21', 'result_22', 'result_23', 'result_24', 'result_33', 'result_35', 'result_37']
#
# --- Node 'evaluate' finished ---
# --- EXTRACT REVIEWS ---
# Fetching: https://de.restaurantguru.com/LOsteria-Regensburg...
# Fetching: https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg...
# Fetching: https://push.bildshopdirekt.de/losteria-regensburg-regensburg/...
# Error loading https://push.bildshopdirekt.de/losteria-regensburg-regensburg/: Status 520
# Fetching: https://schmuck-wendt.de/losteria-regensburg-losteria-neutraubling-speisekarte/...
# Error loading https://schmuck-wendt.de/losteria-regensburg-losteria-neutraubling-speisekarte/: Status 520
# Fetching: https://fr.restaurantguru.com/LOsteria-Regensburg...
# Fetching: https://mappde.com/l-osteria-regensburg-i445661.html...
# Fetching: https://osteria-siciliana-regensburg.wheree.com/...
# Error loading https://osteria-siciliana-regensburg.wheree.com/: Status 403
# Fetching: https://losteria-amberg.wheree.com/...
# Error loading https://losteria-amberg.wheree.com/: Status 403
# Fetching: https://de.restaurantguru.com/LOsteria-Amberg...
# Fetching: https://l-osteria-18.wheree.com/...
# Error loading https://l-osteria-18.wheree.com/: Status 403
# Fetching: https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria...
# Fetching: https://l-osteria-8.wheree.com/...
# Error loading https://l-osteria-8.wheree.com/: Status 403
# Fetching: https://de.restaurantguru.com/LOsteria-Essen...
# Fetching: https://l-osteria-duisburg.wheree.com/...
# Error loading https://l-osteria-duisburg.wheree.com/: Status 403
# Fetching: https://menuweb.menu/restaurants/regensburg/losteria-25...
# Fetching: https://de.restaurantguru.com/Federico-Secondo-Regensburg...
# Fetching: https://restaurantguru.com/LOsteria-Amsterdam...
#
# --- Node 'extract' finished ---
# --- SUMMARIZE ---
#
# --- Node 'summarize' finished ---
#
# ==================================================
# SUMMARY:
# {"summary": "Customer reviews for L'Osteria in Regensburg are mixed, but generally lean positive. Many reviewers (especially recent ones) praise the **delicious pizza, large portions (often XXL), friendly and attentive service, and lively atmosphere**. Several specifically recommend the Barbecue Chicken pizza. A recurring theme is that it's a great place to go with friends and families. \n\nHowever, there are consistent complaints about the **restaurant being very crowded, noisy, and tightly packed**, making it difficult to have a quiet conversation. Some reviewers have experienced **slow or inattentive service**, and a few noted a decline in pizza quality over time – specifically mentioning less generous toppings and dryness. There are also a few isolated complaints about long wait times for food and bills. Accessibility is a concern, as the restrooms are not easily accessible for those with mobility issues.\n\nSeveral reviews also mention that L'Osteria is a popular chain and can be found in multiple cities, with varying experiences across locations. A few reviews are unrelated to L'Osteria Regensburg, discussing Italian food in general or other restaurants.", "overall_sentiment": "Generally positive, with caveats about crowding and potential quality inconsistencies.", "praise": ["Delicious pizza", "Large portions", "Friendly and attentive service", "Lively atmosphere", "Good value for money"], "complaints": ["Crowded and noisy", "Tight seating", "Slow/inattentive service (sometimes)", "Declining pizza quality (less toppings, dryness)", "Accessibility issues (stairs to restrooms)", "Long wait times (occasionally)"]}
#
# ==================================================
# EXTRACTED REVIEWS (59 found):
#
# [1] None
# Stars: 5 | URL: https://de.restaurantguru.com/LOsteria-Regensburg
# Text: Essen super lecker! Mitarbeiter sehr freundlich und aufmerksam!...
#
# [2] None
# Stars: 5 | URL: https://de.restaurantguru.com/LOsteria-Regensburg
# Text: Das Essen ist super lecker und der Service ist sehr aufmerksam....
#
# [3] None
# Stars: 5 | URL: https://de.restaurantguru.com/LOsteria-Regensburg
# Text: Essen gut. Service bemüht sich. Im Winter nicht im Eingangsbereich sitzen. Wheelchair accessibility: Nicht geeignet da die WCs nur über eine enge Trep...
#
# [4] None
# Stars: None | URL: https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg
# Text: Hi Can anyone recommend a good Italian restaurant in Regensburg? TIA...
#
# [5] None
# Stars: None | URL: https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg
# Text: It's like asking for a restaurant with good american food... although it may all be the same there ;-). Do you actually realize how food extremely dif...
#
# Done!

# %%
final_reviews
# Out:
# [{'review_title': None,
#   'review_text': 'Essen super lecker! Mitarbeiter sehr freundlich und aufmerksam!',
#   'stars': 5,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': 'Das Essen ist super lecker und der Service ist sehr aufmerksam.',
#   'stars': 5,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': 'Essen gut. Service bemüht sich. Im Winter nicht im Eingangsbereich sitzen. Wheelchair accessibility: Nicht geeignet da die WCs nur über eine enge Treppe nach unten erreicht werden können. Und im Lokal ist es zu eng.',
#   'stars': 5,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': 'Hi Can anyone recommend a good Italian restaurant in Regensburg? TIA',
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "It's like asking for a restaurant with good american food... although it may all be the same there ;-). Do you actually realize how food extremely differs between regions in a certain country? This being said, for a wonderful sicilian experience, check Osteria Luna Rossa.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "I'm curious as to how else I would ask the question? I understand it differs among different regions, but it is a genre of food that most people identify as pasta and pizza.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "no specific recommendations - I just want to add a humorous story. I live in rural Italy, where it's hard to find anything BUT Italian food. Sometimes I'm just desperate for any type of Asian or really anything with a different flavour profile. So I went to Germany in July eager for some good traditional Bavarian dishes...and every 2nd restaurant was Italian. I was disappointed! I had to go out of my way for German food. Same with the coffee - no more simple kaffee und kuchen, everyplace had lattes, macchiati etc. And everyone was saying ciao instead of Tschüss. All this to say, you won't have trouble finding Italian food but I can't point you a specific one, sorry.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "Nelly- that's so funny!  Doesn't that figure! I noticed that there are so many burger joints in Germany. I like burgers, but I need to change it up. We have 2 teens coming with us and they are not the most adventurous eaters so our choices are sort of limited. We will be trying a German restaurant on Christmas,  but I know that I need to fill in the other days with foods that I know for sure they will enjoy.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "it is a genre of food that most people identify as pasta and pizza OK, now I know what you mean by 'good italian restaurant'. Well, my suggestion in my first reply don't serve pizzas. IMO the best neapolitan pizza is eaten at NineOfive, but they don't serve pasta. As you are looking for pizza AND pasta, maybe check L'Osteria or (a bit outside the centre) Restaurant Valentino.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': "We like L'Osteria and Pizzeria Da Tino.  Recommend reservations.",
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': 'Thank you!',
#   'stars': None,
#   'website_url': 'https://community.ricksteves.com/travel-forum/germany/italian-restaurants-in-regensburg'},
#  {'review_title': None,
#   'review_text': 'Tout etais parfait le manager etais super gentil et la bouffe etais parfaite vraiment le meilleur restaurant italien pour moi a Regensburg.',
#   'stars': 5,
#   'website_url': 'https://fr.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': "Accueil et ambiance chaleureux. Quant aux pizzas, énormes, c'est un régal. A ne pas manquer dans cette très jolie ville. Nous y retournerons sans aucune hésitation",
#   'stars': None,
#   'website_url': 'https://fr.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': "Used to the superb L'Osterias in Prague, I couldn't help but be a bit disappointed by the pizzas here. It was quite ordinary, dry, and completely different. The portion is still huge though, and the place nice.",
#   'stars': 3,
#   'website_url': 'https://fr.restaurantguru.com/LOsteria-Regensburg'},
#  {'review_title': None,
#   'review_text': 'Ich kenne Dampfnudel Ulli nun schon ewig. Service und Speisen immer Klasse. Ulli ist ...',
#   'stars': None,
#   'website_url': 'https://mappde.com/l-osteria-regensburg-i445661.html'},
#  {'review_title': None,
#   'review_text': 'Tolle Dachterrasse. Leider sehr unhöfliches Personal. Essen ist gut aber nicht dem Pr...',
#   'stars': None,
#   'website_url': 'https://mappde.com/l-osteria-regensburg-i445661.html'},
#  {'review_title': None,
#   'review_text': 'Ein sehr schönes feines Restaurant. Toller Service mit sehr freundlicher Bedienung',
#   'stars': None,
#   'website_url': 'https://mappde.com/l-osteria-regensburg-i445661.html'},
#  {'review_title': None,
#   'review_text': 'Das Eiscafé am Dom ist gut besucht und sehr zentral. Man kann jegliche Eissorten find...',
#   'stars': None,
#   'website_url': 'https://mappde.com/l-osteria-regensburg-i445661.html'},
#  {'review_title': None,
#   'review_text': 'Deutsche Küche im urigen Ambiente. Die Portionen waren reichhaltig und lecker und das...',
#   'stars': None,
#   'website_url': 'https://mappde.com/l-osteria-regensburg-i445661.html'},
#  {'review_title': None,
#   'review_text': '

#   'website_url': 'https://de.restaurantguru.com/LOsteria-Amberg'},
#  {'review_title': None,
#   'review_text': "Also passt mal gut auf liebe L'Osteria, ihr wart mal richtig richtig gut, auch wenn man bei euch bestellt hat, das Essen (speziell die Pizza) WAR richtig gut aber mittlerweile komme ich mir ziemlich verarscht vor! Warum? Sag ich euch gerne! Man bezahlt für die Pizza über 15€ und bekommt nicht mal mit 5 km Entfernung ne kalte Pizza (kann ja mal vorkommen) mit absolut minimalen Belag! Was soll das? Ich habe ne Pizza Schinken bestellt, Menge des Belags hat in den letzten Monaten / Jahren stetig abgenommen, aber mittlerweile bekommt man gewürfelten Schinken wie vom Discounter und man hat gerade mal knapp zwei Esslöffel voll auf der ganzen Pizza! Da hilft auch nix das die so groß ist und auf keinen Teller passt! Als nächstes kommen die Dosen Pilze auf der Fungi , top die Wette gilt! Aber man soll ja nicht meckern, dafür lacht mich die Vanessa Mai an auf der Packung, jetzt weiß ich wo das Geld hin kommt bzw. mein Belag, die hat nämlich ordentlich was drauf auf der Pizza, traurig! Ich schreib ja echt nicht viele Rezessionen, aber das musste sein! MfG.",
#   'stars': 2,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Amberg'},
#  {'review_title': None,
#   'review_text': "Wir waren heute das 1. Mal in der L'Osteria Amberg. Wie auch in den L'Osterias München, Nürnberg, Regensburg und Berlin, war der Service zuvorkommend und höflich, die Wartezeit von knapp 15 Minuten angemessen und das Essen, wie gewohnt, sehr lecker.Die negativen Bewertungen können wir nicht nachvollziehen. Aus unserer Sicht absolut empfehlenswert.",
#   'stars': None,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Amberg'},
#  {'review_title': None,
#   'review_text': 'Lecker',
#   'stars': 5,
#   'website_url': 'https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria'},
#  {'review_title': None,
#   'review_text': 'Pizza ist absolut nicht gut.',
#   'stars': 1,
#   'website_url': 'https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria'},
#  {'review_title': None,
#   'review_text': "It was wrongly advertised as L'Osteria. Unfortunately I had to drive there to find it that I'm at the wrong restaurant.",
#   'stars': 1,
#   'website_url': 'https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria'},
#  {'review_title': None,
#   'review_text': 'Kind and friendly service Tasty pasta',
#   'stars': 5,
#   'website_url': 'https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria'},
#  {'review_title': None,
#   'review_text': 'Wir haben',
#   'stars': 5,
#   'website_url': 'https://www.top-rated.online/cities/Nuremberg/place/p/5115762/Osteria'},
#  {'review_title': None,
#   'review_text': 'Das Essen war lecker. Leider wurde der falsche Salat gebracht. Die Preise haben ordentlich angezogen, sodass man mit 2 Pizzen, 2 Tees und einem Mini Salat fast 45€ zahlt. Der Sitzplatz direkt am Eingang war auch nicht so optimal.',
#   'stars': None,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Essen'},
#  {'review_title': None,
#   'review_text': 'Das Essen war göttlich! Super Kellner, total liebenswert alle. Der Laden ist total sauber und bietet daher eine super Atmosphäre. Das Essen wird frisch gemacht und durch die offene Küche kann man bei der hygienischen Zubereitung zugucken. Durch die Sympathie der Mitarbeiter fühlt man sich direkt gut aufgehoben. Der Laden ist einfach nur zum gernhaben und würde hier jedes Mal wieder hin kommen.',
#   'stars': None,
#   'website_url': 'https://de.restaurantguru.com/LOsteria-Essen'},
#  {'review_title': None,
#   'review_text': "Wir haben einen wundervollen Abend im L'Osteria Essen verbracht. Tolle Atmosphäre. Schnelle und sehr freundliche Kellner, leckeres Essen was man selbst mit viel Hunger kaum schafft aufzuessen ( aber auch das war kein Problem der Rest wird einfach eingepackt). Wir kommen sehr gerne wieder und können euch uneingeschränkt weiterempfehlen. Vielen Dank für den tollen Abend.",
#   'stars': None,
#   'website_url': 'https://de.restaurantguru.com
: viel zu klein, dadurch viel zu eng bestuhlt. Die Bedienung rempelte ständig an meinen Stuhl, obwohl ich mich dicht an den Tisch setzte. Eine Entschuldigung blieb natürlich aus. Auch der Versuch, etwas an der Beengtheit zu ändern. Der Kochbereich ist offen und so strömen alle Koch- und Essensgerüche ungehindert in den Gastraum, was dann für stark riechende Kleidung im Anschluss sorgt. Der Gastraum selbst spottet jeglicher Beschreibung: man will einerseits „authentisch italienisch“ sein, sorgt aber mit billiger Dekoration für das Gegenteil. Das mag vielleicht die anspruchslose Hautevolee begeistern. Gemütlichkeit für einen schönen Abend geht aber anders. Dafür ist der Gastraum zu laut und zu beengt.Zum Essen: viel zu teuer. Die Portionen waren für ein Abendessen ideal, nicht zu groß und nicht zu mächtig. Aber der Preis war fast schon unverschämt. Ich hatte eine Steinpilzsuppe vorweg und danach Gnocchi. Beides war in Ordnung, eine kulinarische Herausforderung war es allerdings nicht. Zur Vorspeise wurde uns zu Viert jeweils eine Scheibe Brot zugedacht. Die Weine waren akzeptabel, jedoch auch hier zu teuer. Die Flasche Wasser wurde nicht am Tisch geöffnet sondern kam bereits ohne Verschluss an unseren Tisch. Was mich immer skeptisch macht. Zum Service: viel zu patzig. Wir wurden von zwei jungen Frauen bedient, die höchst wahrscheinlich nicht geschultes oder gar ausgebildetes Gastronomie-Personal ist. Zuerst wurden wir mehrfach ungeduldig von einer Bedienung zur Bestellung aufgefordert. Dann wurde von der anderen Bedienung serviert. Und das in einer ausgesuchten Pampigkeit und Herablassung, dass sich dies natürlich bei mir auch in der Trinkgeldgabe äußerte. Ich gab keines. Auf den Abschiedsgruß aus unserer Gruppe wurde noch nicht einmal reagiert.Fazit: wer solche Preise für Essen und Service verlangt, sollte auch entsprechendes bieten. Was in diesem Lokal allerdings nicht geboten wird. Für ähnliches Geld, vielleicht ein wenig mehr, kann man auf Spitzenniveau in einem Sterne-Restaurant im Turm mit Terrasse und Domblick speisen und erhält dafür noch einen Spitzenservice von topp ausgebildetem und zuvorkommendem Personal. Die „Osteria Federico Secondo“ wird mich als Gast jedenfalls nicht mehr sehen.',
#   'stars': None,
#   'website_url': 'https://de.restaurantguru.com/Federico-Secondo-Regensburg'},
#  {'review_title': None,
#   'review_text': 'Food: 5 Service: 5 Atmosphere: 5',
#   'stars': None,
#   'website_url': 'https://restaurantguru.com/LOsteria-Amsterdam'},
#  {'review_title': None,
#   'review_text': 'Food: 5 Service: 5 Atmosphere: 5',
#   'stars': None,
#   'website_url': 'https://restaurantguru.com/LOsteria-Amsterdam'},
#  {'review_title': None,
#   'review_text': "From the moment we walked into L'Osteria, we felt completely at home. The atmosphere was warm and inviting, with authentic Italian vibes that made us feel like we had stepped into a little corner of Italy right in the heart of Amsterdam. The staff were incredible. Genuine, friendly, and full of that Italian charm. A special mention goes to Greta, who was absolutely wonderful: kind, professional, and always smiling. She made our evening extra special with her attention to detail and warm personality. The food, of course, was fantastic—delicious, generous, and full of flavor, just like you’d expect in Italy. We’ll definitely be coming back. Grazie mille, L’Osteria!",
#   'stars': None,
#   'website_url': 'https://restaurantguru.com/LOsteria-Amsterdam'}]
